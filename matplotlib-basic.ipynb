# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
#import seaborn as sns

#from matplotlib import animation
#mpl.rcParams['figure.figsize'] = (10.0, 10.0)
#plt.style.use('seaborn')
#%matplotlib inline

# %% [markdown]
# ### Analyze: Drinks by County

# %%
# source: https://github.com/fivethirtyeight/data/tree/master/alcohol-consumption
drinksdf = pd.read_csv('./data-files/drinks.csv', skiprows=1, names = ['country', 'beer', 'spirit', 'wine', 'alcohol', 'continent']) 
drinksdf.head()
# Out:
#        country  beer  spirit  wine  alcohol continent
# 0  Afghanistan     0       0     0      0.0      Asia
# 1      Albania    89     132    54      4.9    Europe
# 2      Algeria    25       0    14      0.7    Africa
# 3      Andorra   245     138   312     12.4    Europe
# 4       Angola   217      57    45      5.9    Africa

# %%
drinksdf['total'] = drinksdf.beer + drinksdf.spirit + drinksdf.wine + drinksdf.alcohol
print(drinksdf.shape)
drinksdf.sample(4)
# Out:
# (193, 7)
#      country  beer  spirit  wine  alcohol      continent  total
# 60   Finland   263     133    97     10.0         Europe  503.0
# 3    Andorra   245     138   312     12.4         Europe  707.4
# 23    Brazil   245     145    16      7.2  South America  413.2
# 119    Nepal     5       6     0      0.2           Asia   11.2

# %%
drinksdf.sort_values(by=['total'], inplace = True, ascending=False)
drinksdf.head(4)
# Out:
#            country  beer  spirit  wine  alcohol      continent  total
# 3          Andorra   245     138   312     12.4         Europe  707.4
# 68         Grenada   199     438    28     11.9  North America  676.9
# 45  Czech Republic   361     170   134     11.8         Europe  676.8
# 61          France   127     151   370     11.8         Europe  659.8

# %%
# Lets see top 20 distribution
drinksdf_top10 = drinksdf.iloc[:20]
drinksdf_top10.shape
# Out:
# (20, 7)

# %%
# setup bar graph with X, Y value
plt.bar(drinksdf_top10['country'],drinksdf_top10['total'])

# X-axis label 
plt.xlabel('Country') 

# Y-axis label 
plt.ylabel('Consumption') 

# Plot title 
plt.title('Drinks by Counrty') 

# few touchups
# show grid lines for easy data read
plt.grid(True)
# x-axis label direction
plt.xticks(rotation=90) 

# Display plot now 
plt.show()

# %%
drinksdf.sort_values(by=['total'], ascending=False)['total'].head(10).plot.bar(drinksdf_top10['country'],drinksdf_top10['total'])
# Out:
# <AxesSubplot:>

# %%
drinksdf['beer'].hist()
plt.show()

# %%
drinksdf['beer'].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:>

# %%
#pie plot 
plt.pie([x*100 for x in d_cuisine.values()],labels=[x for x in d_cuisine.keys()],autopct='%0.1f',explode=[0,0,0.1,0]) 

#label the plot 
plt.title('Cuisine share %') 
plt.show()

# %% [markdown]
# ### Analyze Population of districts in India

# %%
populationdf = pd.read_csv("./data-files/census-population.csv")
populationdf.drop(['Subdistt', 'Town/Village', 'Ward', 'EB'], axis=1, inplace=True)
print(populationdf.shape)
populationdf.head(3)
# Out:
# (2028, 24)
#    State  District  Level   Name    TRU      No_HH       TOT_P      TOT_M  \
# 0      0         0  India  India  Total  249501663  1210854977  623270258
# 1      0         0  India  India  Rural  168612897   833748852  427781058
# 2      0         0  India  India  Urban   80888766   377106125  195489200
#
#        TOT_F       P_06  ...      F_SC       P_ST      M_ST      F_ST  \
# 0  587584719  164515253  ...  97843058  104545716  52547215  51998501
# 1  405967794  121322865  ...  74732561   94083844  47263733  46820111
# 2  181616925   43192388  ...  23110497   10461872   5283482   5178390
#
#        P_LIT      M_LIT      F_LIT      P_ILL      M_ILL      F_ILL
# 0  763638812  434763622  328875190  447216165  188506636  258709529
# 1  482793835  281361374  201432461  350955017  146419684  204535333
# 2  280844977  153402248  127442729   96261148   42086952   54174196
#
# [3 rows x 24 columns]
